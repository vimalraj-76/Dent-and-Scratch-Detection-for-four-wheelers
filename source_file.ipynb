# %%
# !curl -L "https://app.roboflow.com/ds/X7lbN6SX2I?key=l6xYhoZeh1" > roboflow.zip; unzip roboflow.zip; rm roboflow.zip

# %%
# !git clone https://github.com/ultralytics/yolov5
# Out:
# fatal: destination path 'yolov5' already exists and is not an empty directory.

# %%
# !python /content/yolov5/train.py --img 416 --batch 64 --epochs 300 --data '/content/data.yaml' --cfg '/content/custom_model.yaml' --weights ''
# Out:
# train: weights=, cfg=/content/custom_model.yaml, data=/content/data.yaml, hyp=yolov5/data/hyps/hyp.scratch-low.yaml, epochs=300, batch_size=64, imgsz=416, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, noplots=False, evolve=None, bucket=, cache=None, image_weights=False, device=, multi_scale=False, single_cls=False, optimizer=SGD, sync_bn=False, workers=8, project=yolov5/runs/train, name=exp, exist_ok=False, quad=False, cos_lr=False, label_smoothing=0.0, patience=100, freeze=[0], save_period=-1, seed=0, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest
# github: up to date with https://github.com/ultralytics/yolov5 ✅
# YOLOv5 🚀 v6.2-187-g5ef69ef Python-3.7.14 torch-1.12.1+cu113 CUDA:0 (Tesla T4, 15110MiB)
#
# ...

# %%
# !python yolov5/detect.py --weights /content/yolov5/runs/train/exp5/weights/best.pt --img 416 --conf 0.4 --source ./test/images
# Out:
# detect: weights=['/content/yolov5/runs/train/exp5/weights/best.pt'], source=./test/images, data=yolov5/data/coco128.yaml, imgsz=[416, 416], conf_thres=0.4, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=yolov5/runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLOv5 🚀 v6.2-187-g5ef69ef Python-3.7.14 torch-1.12.1+cu113 CUDA:0 (Tesla T4, 15110MiB)
#
# Fusing layers...
# custom_model summary: 182 layers, 7249215 parameters, 0 gradients
# image 1/18 /content/test/images/15_jpg.rf.d47b0116ad2c3839c36d7f84df60933c.jpg: 416x416 1 dent, 8.9ms
# image 2/18 /content/test/images/1_jpg.rf.03efa2511735df006963b71939c49619.jpg: 416x416 1 dent, 9.2ms
# image 3/18 /content/test/images/1_jpg.rf.1bf20f087afb3dfce94964ad1f40667f.jpg: 416x416 1 dent, 9.0ms
# ...

# %%
import glob
from IPython.display import Image, display

for imageName in glob.glob('/content/yolov5/runs/detect/exp6/*.jpg'): #assuming JPG
    display(Image(filename=imageName))
    print("\n")

# %%
from google.colab import drive
drive.mount('/content/gdrive')

# %%
# %cp /content/yolov5/runs/train/exp3/weights/best.pt /content/gdrive/My\ Drive
